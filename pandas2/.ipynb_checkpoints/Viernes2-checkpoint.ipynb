# %% [markdown]
# # Merge, Concatenate, Pivot

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Cargamos datos de trafico.
df = pd.read_csv("/home/dsc/Data/us_dot/otp/On_Time_On_Time_Performance_2015_1.csv", sep=',')
# Out:
# /usr/lib64/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (77,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0  2015        1      1           1          4  2015-01-01            AA
# 1  2015        1      1           2          5  2015-01-02            AA
# 2  2015        1      1           3          6  2015-01-03            AA
# 3  2015        1      1           4          7  2015-01-04            AA
# 4  2015        1      1           5          1  2015-01-05            AA
#
#    AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 0      19805      AA  N787AA      ...               NaN          NaN
# 1      19805      AA  N795AA      ...               NaN          NaN
# 2      19805      AA  N788AA      ...               NaN          NaN
# 3      19805      AA  N791AA      ...               NaN          NaN
# 4      19805      AA  N783AA      ...               NaN          NaN
#
#    Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# ...

# %%
df.sample(5)
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 306782  2015        1      1          17          6  2015-01-17            UA
# 90709   2015        1      1           8          4  2015-01-08            DL
# 397622  2015        1      1          23          5  2015-01-23            EV
# 65781   2015        1      1           7          3  2015-01-07            B6
# 125259  2015        1      1          13          2  2015-01-13            US
#
#         AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 306782      19977      UA  N76504      ...               NaN          NaN
# 90709       19790      DL  N694DL      ...               NaN          NaN
# 397622      20366      EV  N18102      ...               NaN          NaN
# 65781       20409      B6  N531JB      ...               NaN          NaN
# 125259      20355      US  N556UW      ...               NaN          NaN
#
# ...

# %%
# Selección de dos columnas
df2 = df[['FlightDate','Carrier']]

# %%
df2.sample(3)
# Out:
#         FlightDate Carrier
# 289766  2015-01-30      OO
# 145727  2015-01-06      WN
# 444248  2015-01-03      MQ

# %%
df2[df2['FlightDate']=='2015-01-22']
# Out:
#         FlightDate Carrier
# 21      2015-01-22      AA
# 52      2015-01-22      AA
# 83      2015-01-22      AA
# 114     2015-01-22      AA
# 145     2015-01-22      AA
# 176     2015-01-22      AA
# 207     2015-01-22      AA
# 238     2015-01-22      AA
# 269     2015-01-22      AA
# 300     2015-01-22      AA
# 331     2015-01-22      AA
# 357     2015-01-22      AA
# 386     2015-01-22      AA
# 417     2015-01-22      AA
# 447     2015-01-22      AA
# 474     2015-01-22      AA
# 503     2015-01-22      AA
# 531     2015-01-22      AA
# 560     2015-01-22      AA
# 591     2015-01-22      AA
# 627     2015-01-22      AA
# 657     2015-01-22      AA
# 681     2015-01-22      AA
# 708     2015-01-22      AA
# 739     2015-01-22      AA
# 770     2015-01-22      AA
# 801     2015-01-22      AA
# 832     2015-01-22      AA
# 863     2015-01-22      AA
# 894     2015-01-22      AA
# ...            ...     ...
# 469127  2015-01-22      MQ
# 469153  2015-01-22      MQ
# ...

# %%
df2[df2['FlightDate']=='2015-01-22'].sample(3)
# Out:
#         FlightDate Carrier
# 355514  2015-01-22      DL
# 38883   2015-01-22      AA
# 229933  2015-01-22      WN

# %%
# tipo de cada columna.
df.dtypes
# Out:
# Year                    int64
# Quarter                 int64
# Month                   int64
# DayofMonth              int64
# DayOfWeek               int64
# FlightDate             object
# UniqueCarrier          object
# AirlineID               int64
# Carrier                object
# TailNum                object
# FlightNum               int64
# OriginAirportID         int64
# OriginAirportSeqID      int64
# OriginCityMarketID      int64
# Origin                 object
# OriginCityName         object
# OriginState            object
# OriginStateFips         int64
# OriginStateName        object
# OriginWac               int64
# DestAirportID           int64
# DestAirportSeqID        int64
# DestCityMarketID        int64
# Dest                   object
# DestCityName           object
# DestState              object
# DestStateFips           int64
# DestStateName          object
# DestWac                 int64
# CRSDepTime              int64
#                        ...
# ...

# %%
# Evolución de vuelos de un día para otro. Uso de Merge para hacer un join.

# %%
df1 = DataFrame(np.random.randint(0,10,3*5).reshape(3,5))
df1.columns = ['c1','c2','c3','c4','c5']
df1
# Out:
#    c1  c2  c3  c4  c5
# 0   9   0   8   1   1
# 1   2   6   7   8   4
# 2   8   6   4   3   8

# %%
df1['key1'] = ['a','a','b']

# %%
df1
# Out:
#    c1  c2  c3  c4  c5 key1
# 0   9   0   8   1   1    a
# 1   2   6   7   8   4    a
# 2   8   6   4   3   8    b

# %%
df2 = DataFrame(np.random.randint(0,10,3*5).reshape(3,5))
df2.columns = ['c1','c2','c3','c4','c5']
df2['key1'] = ['b','a','b']

# %%
df2
# Out:
#    c1  c2  c3  c4  c5 key1
# 0   9   8   8   1   4    b
# 1   4   9   9   4   3    a
# 2   6   4   1   8   7    b

# %%
# Join entre los dos dataframe
pd.merge(df1,df2, on='key1')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1  c1_y  c2_y  c3_y  c4_y  c5_y
# 0     9     0     8     1     1    a     4     9     9     4     3
# 1     2     6     7     8     4    a     4     9     9     4     3
# 2     8     6     4     3     8    b     9     8     8     1     4
# 3     8     6     4     3     8    b     6     4     1     8     7

# %%
pd.merge(df1,df2, on='key1', how='inner')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1  c1_y  c2_y  c3_y  c4_y  c5_y
# 0     9     0     8     1     1    a     4     9     9     4     3
# 1     2     6     7     8     4    a     4     9     9     4     3
# 2     8     6     4     3     8    b     9     8     8     1     4
# 3     8     6     4     3     8    b     6     4     1     8     7

# %%
pd.merge(df1,df2, on='key1', how='left')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1  c1_y  c2_y  c3_y  c4_y  c5_y
# 0     9     0     8     1     1    a     4     9     9     4     3
# 1     2     6     7     8     4    a     4     9     9     4     3
# 2     8     6     4     3     8    b     9     8     8     1     4
# 3     8     6     4     3     8    b     6     4     1     8     7

# %%
pd.merge(df1,df2, on='key1', how='right')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1  c1_y  c2_y  c3_y  c4_y  c5_y
# 0     9     0     8     1     1    a     4     9     9     4     3
# 1     2     6     7     8     4    a     4     9     9     4     3
# 2     8     6     4     3     8    b     9     8     8     1     4
# 3     8     6     4     3     8    b     6     4     1     8     7

# %%
pd.merge(df1,df2, on='key1', how='outer')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1  c1_y  c2_y  c3_y  c4_y  c5_y
# 0     9     0     8     1     1    a     4     9     9     4     3
# 1     2     6     7     8     4    a     4     9     9     4     3
# 2     8     6     4     3     8    b     9     8     8     1     4
# 3     8     6     4     3     8    b     6     4     1     8     7

# %%
# Podemos seleccionar columnas en caso de que no haya ninguna común.
df2['key2'] = df2['key1']

# %%
pd.merge(df1, df2, left_on='key1', right_on='key2')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1_x  c1_y  c2_y  c3_y  c4_y  c5_y key1_y  \
# 0     9     0     8     1     1      a     4     9     9     4     3      a
# 1     2     6     7     8     4      a     4     9     9     4     3      a
# 2     8     6     4     3     8      b     9     8     8     1     4      b
# 3     8     6     4     3     8      b     6     4     1     8     7      b
#
#   key2
# 0    a
# 1    a
# 2    b
# 3    b

# %%
pd.merge(df1, df2, left_on='key1', right_on='key2', suffixes=('izda','dcha'))
# Out:
#    c1izda  c2izda  c3izda  c4izda  c5izda key1izda  c1dcha  c2dcha  c3dcha  \
# 0       9       0       8       1       1        a       4       9       9
# 1       2       6       7       8       4        a       4       9       9
# 2       8       6       4       3       8        b       9       8       8
# 3       8       6       4       3       8        b       6       4       1
#
#    c4dcha  c5dcha key1dcha key2
# 0       4       3        a    a
# 1       4       3        a    a
# 2       1       4        b    b
# 3       8       7        b    b

# %%
# Añadir una fila y key2 tenga 
df2
# Out:
#    c1  c2  c3  c4  c5 key1 key2
# 0   9   8   8   1   4    b    b
# 1   4   9   9   4   3    a    a
# 2   6   4   1   8   7    b    b

# %%
df2.append({'c1':2,'c2':3,'c3':5,'c4':6,'c5':2,'key1':'d','key2':'c'},ignore_index= True)
# Out:
#    c1  c2  c3  c4  c5 key1 key2
# 0   9   8   8   1   4    b    b
# 1   4   9   9   4   3    a    a
# 2   6   4   1   8   7    b    b
# 3   2   3   5   6   2    d    c

# %%
df1['key2'] = 'e'

# %%
df1
# Out:
#    c1  c2  c3  c4  c5 key1 key2
# 0   9   0   8   1   1    a    e
# 1   2   6   7   8   4    a    e
# 2   8   6   4   3   8    b    e

# %%
# apilar dataframes
pd.concat([df1, df2], ignore_index=True)
# Out:
#    c1  c2  c3  c4  c5 key1 key2
# 0   9   0   8   1   1    a    e
# 1   2   6   7   8   4    a    e
# 2   8   6   4   3   8    b    e
# 3   9   8   8   1   4    b    b
# 4   4   9   9   4   3    a    a
# 5   6   4   1   8   7    b    b

# %%
pd.merge(df1, df2, left_on='key1', right_on='key2', how='inner')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1_x key2_x  c1_y  c2_y  c3_y  c4_y  c5_y  \
# 0     9     0     8     1     1      a      e     4     9     9     4     3
# 1     2     6     7     8     4      a      e     4     9     9     4     3
# 2     8     6     4     3     8      b      e     9     8     8     1     4
# 3     8     6     4     3     8      b      e     6     4     1     8     7
#
#   key1_y key2_y
# 0      a      a
# 1      a      a
# 2      b      b
# 3      b      b

# %%
pd.merge(df1, df2, left_on='key1', right_on='key2', how='outer')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1_x key2_x  c1_y  c2_y  c3_y  c4_y  c5_y  \
# 0     9     0     8     1     1      a      e     4     9     9     4     3
# 1     2     6     7     8     4      a      e     4     9     9     4     3
# 2     8     6     4     3     8      b      e     9     8     8     1     4
# 3     8     6     4     3     8      b      e     6     4     1     8     7
#
#   key1_y key2_y
# 0      a      a
# 1      a      a
# 2      b      b
# 3      b      b

# %%
# group by importante!!!!!
len(df)
# Out:
# 469968

# %%
# datos para el 22 de enero.
minidf = df[df.FlightDate == "2015-01-22"]

# %%
len(minidf)
# Out:
# 16013

# %%
# Vuelos para cada aerolínea.
by_carrier = minidf.groupby("Carrier")

# %%
# es un objeto perezoso, se ejecuta cuando le pides cosas..
by_carrier

# %%
by_carrier.get_group('AA').sample(5)
# Out:
#        Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 21466  2015        1      1          22          4  2015-01-22            AA
# 19751  2015        1      1          22          4  2015-01-22            AA
# 17974  2015        1      1          22          4  2015-01-22            AA
# 19098  2015        1      1          22          4  2015-01-22            AA
# 6897   2015        1      1          22          4  2015-01-22            AA
#
#        AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 21466      19805      AA  N5DXAA      ...               NaN          NaN
# 19751      19805      AA  N4WNAA      ...               NaN          NaN
# 17974      19805      AA  N4YBAA      ...               NaN          NaN
# 19098      19805      AA  N3FXAA      ...               NaN          NaN
# 6897       19805      AA  N3KEAA      ...               NaN          NaN
#
# ...

# %%
# todas las llaves por las que ha agrupado.
by_carrier.groups.keys()
# Out:
# ['AA',
#  'OO',
#  'DL',
#  'NK',
#  'HA',
#  'WN',
#  'B6',
#  'US',
#  'AS',
#  'MQ',
#  'F9',
#  'VX',
#  'EV',
#  'UA']

# %%
# Se puede agrupar por varias columnas
df.groupby(["Carrier", "Origin"])

# %%
# Funciones de DataFrame groupby
by_carrier.sum()
# Out:
#             Year  Quarter  Month  DayofMonth  DayOfWeek  AirlineID  FlightNum  \
# Carrier
# AA       2907645     1443   1443       31746       5772   28578615    1814608
# AS        878540      436    436        9592       1744    8689480     190953
# B6       1430650      710    710       15620       2840   14490390     645334
# DL       4642560     2304   2304       50688       9216   45596160    3818469
# EV       3481920     1728   1728       38016       6912   35192448    8412289
# F9        449345      223    223        4906        892    4557228     178800
# HA        419120      208    208        4576        832    4095520      47658
# MQ       2033135     1009   1009       22198       4036   20581582    3321753
# NK        566215      281    281        6182       1124    5736896     149452
# OO       3256240     1616   1616       35552       6464   32811264    8272753
# UA       2710175     1345   1345       29590       5380   26869065    1348184
# ...

# %%
# Uso de ciertas columnas.
len(by_carrier.get_group('AA'))
# Out:
# 1443

# %%
# Numero de vuelos de cada Carrier, se puede usar cualquier columna, pues todas tienen valores.
NumberOfFlight = by_carrier.Year.count()

# %%
NumberOfFlight
# Out:
# Carrier
# AA    1443
# AS     436
# B6     710
# DL    2304
# EV    1728
# F9     223
# HA     208
# MQ    1009
# NK     281
# OO    1616
# UA    1345
# US    1171
# VX     163
# WN    3376
# Name: Year, dtype: int64

# %%
# Hacemos lo mismo pero con apply
def dflength(df):
    return len(df)

# %%
by_carrier.apply(dflength)
# numero de vuelos por aerolínea en el 22 de enero.
# Out:
# Carrier
# AA    1443
# AS     436
# B6     710
# DL    2304
# EV    1728
# F9     223
# HA     208
# MQ    1009
# NK     281
# OO    1616
# UA    1345
# US    1171
# VX     163
# WN    3376
# dtype: int64

# %%
minidf3 = df[df.FlightDate == "2015-01-23"]

# %%
by_carrier23 = minidf3.groupby("Carrier")

# %%
by_carrier23

# %%
len(by_carrier23.get_group('AA'))
# Out:
# 1445

# %%
NumberOfFlight23 = by_carrier23.Year.count()

# %%
NumberOfFlight23
# Out:
# Carrier
# AA    1445
# AS     439
# B6     709
# DL    2303
# EV    1743
# F9     229
# HA     222
# MQ    1010
# NK     285
# OO    1625
# UA    1345
# US    1170
# VX     167
# WN    3364
# Name: Year, dtype: int64

# %%
# resset_index pasa serie a dataframe.
df22jan = by_carrier.apply(dflength).reset_index()

# %%
df22jan
# Out:
#    Carrier     0
# 0       AA  1443
# 1       AS   436
# 2       B6   710
# 3       DL  2304
# 4       EV  1728
# 5       F9   223
# 6       HA   208
# 7       MQ  1009
# 8       NK   281
# 9       OO  1616
# 10      UA  1345
# 11      US  1171
# 12      VX   163
# 13      WN  3376

# %%
df22jan.columns = ['Carrier', 'NumberFlights']

# %%
df23jan = by_carrier23.apply(dflength).reset_index()

# %%
df22jan
# Out:
#    Carrier  NumberFlights
# 0       AA           1443
# 1       AS            436
# 2       B6            710
# 3       DL           2304
# 4       EV           1728
# 5       F9            223
# 6       HA            208
# 7       MQ           1009
# 8       NK            281
# 9       OO           1616
# 10      UA           1345
# 11      US           1171
# 12      VX            163
# 13      WN           3376

# %%
df23jan.columns = ['Carrier', 'NumberFlights']

# %%
df23jan
# Out:
#    Carrier  NumberFlights
# 0       AA           1445
# 1       AS            439
# 2       B6            709
# 3       DL           2303
# 4       EV           1743
# 5       F9            229
# 6       HA            222
# 7       MQ           1010
# 8       NK            285
# 9       OO           1625
# 10      UA           1345
# 11      US           1170
# 12      VX            167
# 13      WN           3364

# %%
pd.merge(df22jan, df23jan, on='Carrier')
# Out:
#    Carrier  NumberFlights_x  NumberFlights_y
# 0       AA             1443             1445
# 1       AS              436              439
# 2       B6              710              709
# 3       DL             2304             2303
# 4       EV             1728             1743
# 5       F9              223              229
# 6       HA              208              222
# 7       MQ             1009             1010
# 8       NK              281              285
# 9       OO             1616             1625
# 10      UA             1345             1345
# 11      US             1171             1170
# 12      VX              163              167
# 13      WN             3376             3364

# %%
evodf = pd.merge(df22jan, df23jan, on='Carrier')

# %%
evodf.columns = ['Carrier','22Jan','23Jan']

# %%
evodf
# Out:
#    Carrier  22Jan  23Jan
# 0       AA   1443   1445
# 1       AS    436    439
# 2       B6    710    709
# 3       DL   2304   2303
# 4       EV   1728   1743
# 5       F9    223    229
# 6       HA    208    222
# 7       MQ   1009   1010
# 8       NK    281    285
# 9       OO   1616   1625
# 10      UA   1345   1345
# 11      US   1171   1170
# 12      VX    163    167
# 13      WN   3376   3364

# %%
# Evol. mes actual - mes anterior / mes anterior
evodf['Evol'] = ((evodf['23Jan'] - evodf['22Jan'])/evodf['22Jan']) * 100
evodf
# Out:
#    Carrier  22Jan  23Jan      Evol
# 0       AA   1443   1445  0.138600
# 1       AS    436    439  0.688073
# 2       B6    710    709 -0.140845
# 3       DL   2304   2303 -0.043403
# 4       EV   1728   1743  0.868056
# 5       F9    223    229  2.690583
# 6       HA    208    222  6.730769
# 7       MQ   1009   1010  0.099108
# 8       NK    281    285  1.423488
# 9       OO   1616   1625  0.556931
# 10      UA   1345   1345  0.000000
# 11      US   1171   1170 -0.085397
# 12      VX    163    167  2.453988
# 13      WN   3376   3364 -0.355450

# %%
def dec2(n):
    return round(n,2)

# %%
# esto es para aplicar apply porque se hace directo.
# evodf['Evol'] = ((evodf['23Jan'] - evodf['22Jan'])/evodf['22Jan']) * 100.round(2)
evodf["Evolution"] = evodf.Evol.apply(dec2)

# %%
evodf
# Out:
#    Carrier  22Jan  23Jan      Evol  Evolution
# 0       AA   1443   1445  0.138600       0.14
# 1       AS    436    439  0.688073       0.69
# 2       B6    710    709 -0.140845      -0.14
# 3       DL   2304   2303 -0.043403      -0.04
# 4       EV   1728   1743  0.868056       0.87
# 5       F9    223    229  2.690583       2.69
# 6       HA    208    222  6.730769       6.73
# 7       MQ   1009   1010  0.099108       0.10
# 8       NK    281    285  1.423488       1.42
# 9       OO   1616   1625  0.556931       0.56
# 10      UA   1345   1345  0.000000       0.00
# 11      US   1171   1170 -0.085397      -0.09
# 12      VX    163    167  2.453988       2.45
# 13      WN   3376   3364 -0.355450      -0.36

# %%
evodf.sort("Evolution", ascending = False)
# Out:
#    Carrier  22Jan  23Jan      Evol  Evolution
# 6       HA    208    222  6.730769       6.73
# 5       F9    223    229  2.690583       2.69
# 12      VX    163    167  2.453988       2.45
# 8       NK    281    285  1.423488       1.42
# 4       EV   1728   1743  0.868056       0.87
# 1       AS    436    439  0.688073       0.69
# 9       OO   1616   1625  0.556931       0.56
# 0       AA   1443   1445  0.138600       0.14
# 7       MQ   1009   1010  0.099108       0.10
# 10      UA   1345   1345  0.000000       0.00
# 3       DL   2304   2303 -0.043403      -0.04
# 11      US   1171   1170 -0.085397      -0.09
# 2       B6    710    709 -0.140845      -0.14
# 13      WN   3376   3364 -0.355450      -0.36

# %%
def evo(s):
    return (s['23Jan']- s['22Jan'])/s['22Jan']

# %%
fila = evodf.ix[9]

# %%
fila
# Out:
# Carrier             OO
# 22Jan             1616
# 23Jan             1625
# Evol         0.5569307
# Evolution         0.56
# Name: 9, dtype: object

# %%
evo(fila)
# Out:
# 0

# %%
# Ejecutamos a todas las filas del dataframe
evodf.apply(evo,axis = 1)
# Out:
# 0     0
# 1     0
# 2    -1
# 3    -1
# 4     0
# 5     0
# 6     0
# 7     0
# 8     0
# 9     0
# 10    0
# 11   -1
# 12    0
# 13   -1
# dtype: int64

# %%
evodf
# Out:
#    Carrier  22Jan  23Jan      Evol  Evolution
# 0       AA   1443   1445  0.138600       0.14
# 1       AS    436    439  0.688073       0.69
# 2       B6    710    709 -0.140845      -0.14
# 3       DL   2304   2303 -0.043403      -0.04
# 4       EV   1728   1743  0.868056       0.87
# 5       F9    223    229  2.690583       2.69
# 6       HA    208    222  6.730769       6.73
# 7       MQ   1009   1010  0.099108       0.10
# 8       NK    281    285  1.423488       1.42
# 9       OO   1616   1625  0.556931       0.56
# 10      UA   1345   1345  0.000000       0.00
# 11      US   1171   1170 -0.085397      -0.09
# 12      VX    163    167  2.453988       2.45
# 13      WN   3376   3364 -0.355450      -0.36

# %%
evodf["Evolution2"] = evodf.apply(evo, axis=1)

# %%
evodf
# Out:
#    Carrier  22Jan  23Jan      Evol  Evolution  Evolution2
# 0       AA   1443   1445  0.138600       0.14           0
# 1       AS    436    439  0.688073       0.69           0
# 2       B6    710    709 -0.140845      -0.14          -1
# 3       DL   2304   2303 -0.043403      -0.04          -1
# 4       EV   1728   1743  0.868056       0.87           0
# 5       F9    223    229  2.690583       2.69           0
# 6       HA    208    222  6.730769       6.73           0
# 7       MQ   1009   1010  0.099108       0.10           0
# 8       NK    281    285  1.423488       1.42           0
# 9       OO   1616   1625  0.556931       0.56           0
# 10      UA   1345   1345  0.000000       0.00           0
# 11      US   1171   1170 -0.085397      -0.09          -1
# 12      VX    163    167  2.453988       2.45           0
# 13      WN   3376   3364 -0.355450      -0.36          -1

# %%
# Plotear evolución 3
loc = range(len(evodf))
plt.bar(loc, evodf.Evolution)
plt.xticks(loc, evodf.Carrier)
plt.show()

# %%
# Plotear evolución 3 ordenado.
# Importante el reset_index, sino no mueve las etiquetas de abajo!!!!!!!!!!
evodfs = evodf.sort("Evolution", ascending = False).reset_index()
loc = range(len(evodfs))
plt.bar(loc, evodfs.Evolution)
plt.xticks(loc, evodfs.Carrier)
plt.show()

# %%
by_carrier.agg(['mean','count'])
# Out:
#          Year       Quarter       Month       DayofMonth       DayOfWeek  \
#          mean count    mean count  mean count       mean count      mean
# Carrier
# AA       2015  1443       1  1443     1  1443         22  1443         4
# AS       2015   436       1   436     1   436         22   436         4
# B6       2015   710       1   710     1   710         22   710         4
# DL       2015  2304       1  2304     1  2304         22  2304         4
# EV       2015  1728       1  1728     1  1728         22  1728         4
# F9       2015   223       1   223     1   223         22   223         4
# HA       2015   208       1   208     1   208         22   208         4
# MQ       2015  1009       1  1009     1  1009         22  1009         4
# NK       2015   281       1   281     1   281         22   281         4
# OO       2015  1616       1  1616     1  1616         22  1616         4
# UA       2015  1345       1  1345     1  1345         22  1345         4
# ...

# %%
# En group_by se selecciona igual que en un DF.
by_carrier.FlightDate

# %%
# Valores para una sola columna.
by_carrier['DayofMonth'].agg(['mean','count','size'])
# Out:
#          mean  count  size
# Carrier
# AA         22   1443  1443
# AS         22    436   436
# B6         22    710   710
# DL         22   2304  2304
# EV         22   1728  1728
# F9         22    223   223
# HA         22    208   208
# MQ         22   1009  1009
# NK         22    281   281
# OO         22   1616  1616
# UA         22   1345  1345
# US         22   1171  1171
# VX         22    163   163
# WN         22   3376  3376

# %%
daystatistics = by_carrier['DayofMonth'].agg(['mean','count','size'])

# %%
daystatistics['Coverage']= np.round(100*daystatistics['count']/sum(daystatistics['count']),2)

# %%
daystatistics
# Out:
#          mean  count  size  Coverage
# Carrier
# AA         22   1443  1443      9.01
# AS         22    436   436      2.72
# B6         22    710   710      4.43
# DL         22   2304  2304     14.39
# EV         22   1728  1728     10.79
# F9         22    223   223      1.39
# HA         22    208   208      1.30
# MQ         22   1009  1009      6.30
# NK         22    281   281      1.75
# OO         22   1616  1616     10.09
# UA         22   1345  1345      8.40
# US         22   1171  1171      7.31
# VX         22    163   163      1.02
# WN         22   3376  3376     21.08

# %%
# Recorrer todos los elementos.
for key, df in by_carrier:
    print df.head()
# Out:
#      Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 21   2015        1      1          22          4  2015-01-22            AA
# 52   2015        1      1          22          4  2015-01-22            AA
# 83   2015        1      1          22          4  2015-01-22            AA
# 114  2015        1      1          22          4  2015-01-22            AA
# 145  2015        1      1          22          4  2015-01-22            AA
#
#      AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 21       19805      AA  N790AA      ...               NaN          NaN
# 52       19805      AA  N783AA      ...               NaN          NaN
# 83       19805      AA  N788AA      ...               NaN          NaN
# 114      19805      AA  N785AA      ...               NaN          NaN
# 145      19805      AA  N377AA      ...               NaN          NaN
#
#      Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# ...
